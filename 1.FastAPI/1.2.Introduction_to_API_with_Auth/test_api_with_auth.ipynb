# %%
import json
import requests
import os
import dotenv

# %%
dotenv = dotenv.load_dotenv()

# %% [markdown]
# ### API 1: The Lord Of The Rings

# %%
url = "https://the-one-api.dev/v2/movie"

One_API_KEY = os.getenv("One_API_KEY")
payload = {}
headers = {
  'Authorization': One_API_KEY
}

response = requests.request("GET", url, headers=headers, data=payload)
response.status_code

# %%
response.text

# %% [markdown]
# ### API 2: IconFinder

# %%
url = "https://api.iconfinder.com/v4/icons/search?query=arrow&count=10"

IconFinder_API_KEY = os.getenv("IconFinder_API_KEY")
headers = {
    "accept": "application/json",
    "Authorization": IconFinder_API_KEY
}

response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()

# %% [markdown]
# ### API 3: Illusion Diffusion

# %%
url = "https://54285744-illusion-diffusion.gateway.alpha.fal.ai/"

payload = {
    "image_url": "https://storage.googleapis.com/falserverless/illusion-examples/pattern.png",
    "prompt": "(masterpiece:1.4), (best quality), (detailed), landscape, Rainy forest of northern Canada",
    "negative_prompt": "(worst quality, poor details:1.4), lowres, (artist name, signature, watermark:1.4), bad-artist-anime, bad_prompt_version2, bad-hands-5, ng_deepnegative_v1_75t"
}

# %%
# Status Code 401 - Unauthorized
headers = {
    "Authorization": "Key 38dc8f4f4-44e2-4117-93e2-9f596711a7cf:ed37c4f04459dae4818886cb7247bdc0",
    "Content-Type": "application/json"
}
response = requests.post(url, json=payload, headers=headers)
response.status_code

# %%
# Status Code 200 - OK
Fal_API_KEY = os.getenv("Fal_API_KEY")
headers = {
    "Authorization": Fal_API_KEY,
    "Content-Type": "application/json"
}
response = requests.post(url, json=payload, headers=headers)
response.status_code

# %%
json.loads(response.text)

# %% [markdown]
# ### API 4: D-ID

# %%
url = "https://api.d-id.com/clips"
payload = {
    "script": {
        "type": "text",
        "provider": {
            "type": "microsoft",
            "voice_id": "en-US-JennyNeural"
        },
        "ssml": "false",
        "input": "Hello there. I am your Smart Assistant. How can I help you?"
    },
    "config": { "result_format": "mp4" },
    "presenter_config": { "crop": { "type": "wide" } },
    "background": { "color": "false" },
    "presenter_id": "anita-6_uTzyZtNR"
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": "Basic bW1fYW1pbmlAc2Vuc29tYXR0LmNvbQ:QjRqs7mGIKynx7nOg5zr9"
}
response = requests.post(url, json=payload, headers=headers)
response.status_code

# %%
response.json()

# %%
url = "https://api.d-id.com/clips/clp_xDZ0sfWokWpUE-c7T6g14"

headers = {
    "accept": "application/json",
    "authorization": "Basic bW1fYW1pbmlAc2Vuc29tYXR0LmNvbQ:QjRqs7mGIKynx7nOg5zr9"
}

response = requests.get(url, headers=headers)
response.status_code

# %%
response.json()

# %% [markdown]
# ### API 5: PlantNet

# %%
url = "https://my-api.plantnet.org/v2/identify/all"

PlantNet_API_KEY = os.getenv("PlantNet_API_KEY")
payload = {
    "api-key": PlantNet_API_KEY
}

headers = {
}

files = {
    'images': open('./io/input/image1.jpg','rb')
}

response = requests.post(url, params=payload, headers=headers, files=files)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'query': {'project': 'all',
#   'images': ['a2ddd26379ee41766750c9c037a92814'],
#   'organs': ['auto'],
#   'includeRelatedImages': False,
#   'noReject': False},
#  'language': 'en',
#  'preferedReferential': 'k-world-flora',
#  'bestMatch': 'Dracaena trifasciata (Prain) Mabb.',
#  'results': [{'score': 0.2387,
#    'species': {'scientificNameWithoutAuthor': 'Dracaena trifasciata',
#     'scientificNameAuthorship': '(Prain) Mabb.',
#     'genus': {'scientificNameWithoutAuthor': 'Dracaena',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dracaena'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Mother in laws tongue',
#      'Snake plant',
#      'African bowstring hemp'],
#     'scientificName': 'Dracaena trifasciata (Prain) Mabb.'},
#    'gbif': {'id': '11041822'},
#    'powo': {'id': '77164235-1'}},
#   {'score': 0.111,
#    'species': {'scientificNameWithoutAuthor': 'Dracaena stuckyi',
#     'scientificNameAuthorship': '(God.-Leb.) Byng & Christenh.',
#     'genus': {'scientificNameWithoutAuthor': 'Dracaena',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dracaena'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Snake plant',
#      "Mother-in-Law's Tongue",
#      'Stuckyi Snake Plant'],
#     'scientificName': 'Dracaena stuckyi (God.-Leb.) Byng & Christenh.'},
#    'gbif': {'id': '11064950'},
#    'powo': {'id': '77183329-1'}},
#   {'score': 0.02254,
#    'species': {'scientificNameWithoutAuthor': 'Dracaena masoniana',
#     'scientificNameAuthorship': '(Chahin.) Byng & Christenh.',
#     'genus': {'scientificNameWithoutAuthor': 'Dracaena',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dracaena'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Whale Fin Plant'],
#     'scientificName': 'Dracaena masoniana (Chahin.) Byng & Christenh.'},
#    'gbif': {'id': '10956312'},
#    'powo': {'id': '77183391-1'}},
#   {'score': 0.01332,
#    'species': {'scientificNameWithoutAuthor': 'Dracaena braunii',
#     'scientificNameAuthorship': 'Engl.',
#     'genus': {'scientificNameWithoutAuthor': 'Dracaena',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dracaena'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Lucky Bamboo', 'Bamboo', 'Green dragon'],
#     'scientificName': 'Dracaena braunii Engl.'},
#    'gbif': {'id': '5304712'},
#    'powo': {'id': '534129-1'}},
#   {'score': 0.00811,
#    'species': {'scientificNameWithoutAuthor': 'Agave guiengola',
#     'scientificNameAuthorship': 'Gentry',
#     'genus': {'scientificNameWithoutAuthor': 'Agave',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Agave'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Silvery agave'],
#     'scientificName': 'Agave guiengola Gentry'},
#    'gbif': {'id': '2767160'},
#    'powo': {'id': '6512-2'},
#    'iucn': {'id': '22486574', 'category': 'EN'}},
#   {'score': 0.00747,
#    'species': {'scientificNameWithoutAuthor': 'Agave demeesteriana',
#     'scientificNameAuthorship': 'Jacobi',
#     'genus': {'scientificNameWithoutAuthor': 'Agave',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Agave'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Navajo Princess'],
#     'scientificName': 'Agave demeesteriana Jacobi'},
#    'gbif': {'id': '2766717'},
#    'powo': {'id': '61919-1'}},
#   {'score': 0.00713,
#    'species': {'scientificNameWithoutAuthor': 'Dracaena pinguicula',
#     'scientificNameAuthorship': '(P.R.O.Bally) Byng & Christenh.',
#     'genus': {'scientificNameWithoutAuthor': 'Dracaena',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dracaena'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': [],
#     'scientificName': 'Dracaena pinguicula (P.R.O.Bally) Byng & Christenh.'},
#    'gbif': {'id': '11027906'},
#    'powo': {'id': '77183625-1'}},
#   {'score': 0.0066,
#    'species': {'scientificNameWithoutAuthor': 'Agave americana',
#     'scientificNameAuthorship': 'L.',
#     'genus': {'scientificNameWithoutAuthor': 'Agave',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Agave'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Agave',
#      'American century plant',
#      'آگاو آمریکایی یا ابلق'],
#     'scientificName': 'Agave americana L.'},
#    'gbif': {'id': '2767031'},
#    'powo': {'id': '319063-2'},
#    'iucn': {'id': '13507070', 'category': 'LC'}},
#   {'score': 0.00448,
#    'species': {'scientificNameWithoutAuthor': 'Phalaenopsis × singuliflora',
#     'scientificNameAuthorship': 'J.J.Sm.',
#     'genus': {'scientificNameWithoutAuthor': 'Phalaenopsis',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Phalaenopsis'},
#     'family': {'scientificNameWithoutAuthor': 'Orchidaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Orchidaceae'},
#     'commonNames': ['Moth Orchid', 'Orchidea', 'ارکیده دو رنگ'],
#     'scientificName': 'Phalaenopsis × singuliflora J.J.Sm.'},
#    'gbif': {'id': '5310894'},
#    'powo': {'id': '650593-1'}},
#   {'score': 0.00446,
#    'species': {'scientificNameWithoutAuthor': 'Furcraea foetida',
#     'scientificNameAuthorship': '(L.) Haw.',
#     'genus': {'scientificNameWithoutAuthor': 'Furcraea',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Furcraea'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Mauritius-hemp', 'Giant cabuya', 'Green-aloe'],
#     'scientificName': 'Furcraea foetida (L.) Haw.'},
#    'gbif': {'id': '2769796'},
#    'powo': {'id': '64429-1'}},
#   {'score': 0.00389,
#    'species': {'scientificNameWithoutAuthor': 'Agave attenuata',
#     'scientificNameAuthorship': 'Salm-Dyck',
#     'genus': {'scientificNameWithoutAuthor': 'Agave',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Agave'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ["Elephant's trunk", 'Foxtail Agave', 'Foxtail'],
#     'scientificName': 'Agave attenuata Salm-Dyck'},
#    'gbif': {'id': '2766613'},
#    'powo': {'id': '61824-1'},
#    'iucn': {'id': '114936958', 'category': 'LC'}},
#   {'score': 0.00375,
#    'species': {'scientificNameWithoutAuthor': 'Dracaena fragrans',
#     'scientificNameAuthorship': '(L.) Ker Gawl.',
#     'genus': {'scientificNameWithoutAuthor': 'Dracaena',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dracaena'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Corn plant', 'Fragrant dracaena', 'Dracaena'],
#     'scientificName': 'Dracaena fragrans (L.) Ker Gawl.'},
#    'gbif': {'id': '5304583'},
#    'powo': {'id': '534207-1'},
#    'iucn': {'id': '144296082', 'category': 'LC'}},
#   {'score': 0.00355,
#    'species': {'scientificNameWithoutAuthor': 'Drimia maritima',
#     'scientificNameAuthorship': '(L.) Stearn',
#     'genus': {'scientificNameWithoutAuthor': 'Drimia',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Drimia'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Red-squill', 'Sea-onion', 'Sea-squill'],
#     'scientificName': 'Drimia maritima (L.) Stearn'},
#    'gbif': {'id': '2776790'},
#    'powo': {'id': '534538-1'},
#    'iucn': {'id': '202953', 'category': 'LC'}},
#   {'score': 0.00338,
#    'species': {'scientificNameWithoutAuthor': 'Tulipa gesneriana',
#     'scientificNameAuthorship': 'L.',
#     'genus': {'scientificNameWithoutAuthor': 'Tulipa',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Tulipa'},
#     'family': {'scientificNameWithoutAuthor': 'Liliaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Liliaceae'},
#     'commonNames': ["Didier's tulip", 'Garden tulip', 'Tulip'],
#     'scientificName': 'Tulipa gesneriana L.'},
#    'gbif': {'id': '5299675'},
#    'powo': {'id': '542923-1'}},
#   {'score': 0.00271,
#    'species': {'scientificNameWithoutAuthor': 'Agave salmiana',
#     'scientificNameAuthorship': 'Otto ex Salm-Dyck',
#     'genus': {'scientificNameWithoutAuthor': 'Agave',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Agave'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Pulque agave'],
#     'scientificName': 'Agave salmiana Otto ex Salm-Dyck'},
#    'gbif': {'id': '2766660'},
#    'powo': {'id': '62247-1'},
#    'iucn': {'id': '115690583', 'category': 'LC'}},
#   {'score': 0.00269,
#    'species': {'scientificNameWithoutAuthor': 'Gonialoe variegata',
#     'scientificNameAuthorship': '(L.) Boatwr. & J.C.Manning',
#     'genus': {'scientificNameWithoutAuthor': 'Gonialoe',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Gonialoe'},
#     'family': {'scientificNameWithoutAuthor': 'Asphodelaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asphodelaceae'},
#     'commonNames': ['Aloe variegata', 'Kanniedood aloe', 'Partridge aloe'],
#     'scientificName': 'Gonialoe variegata (L.) Boatwr. & J.C.Manning'},
#    'gbif': {'id': '9528502'},
#    'powo': {'id': '77142517-1'}},
#   {'score': 0.00259,
#    'species': {'scientificNameWithoutAuthor': 'Dracaena hyacinthoides',
#     'scientificNameAuthorship': '(L.) Mabb.',
#     'genus': {'scientificNameWithoutAuthor': 'Dracaena',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dracaena'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Snake plant'],
#     'scientificName': 'Dracaena hyacinthoides (L.) Mabb.'},
#    'gbif': {'id': '10754273'},
#    'powo': {'id': '77164234-1'}},
#   {'score': 0.00237,
#    'species': {'scientificNameWithoutAuthor': 'Aspidistra elatior',
#     'scientificNameAuthorship': 'Blume',
#     'genus': {'scientificNameWithoutAuthor': 'Aspidistra',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Aspidistra'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Cast-iron-plant', 'Barroomplant', 'Cast Iron Plant'],
#     'scientificName': 'Aspidistra elatior Blume'},
#    'gbif': {'id': '2769937'},
#    'powo': {'id': '531586-1'}},
#   {'score': 0.00191,
#    'species': {'scientificNameWithoutAuthor': 'Haemanthus albiflos',
#     'scientificNameAuthorship': 'Jacq.',
#     'genus': {'scientificNameWithoutAuthor': 'Haemanthus',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Haemanthus'},
#     'family': {'scientificNameWithoutAuthor': 'Amaryllidaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Amaryllidaceae'},
#     'commonNames': ['The Paintbrush Plant', 'Paintbrush'],
#     'scientificName': 'Haemanthus albiflos Jacq.'},
#    'gbif': {'id': '2855156'},
#    'powo': {'id': '64682-1'}},
#   {'score': 0.00178,
#    'species': {'scientificNameWithoutAuthor': 'Philodendron cordatum',
#     'scientificNameAuthorship': 'Kunth ex Schott',
#     'genus': {'scientificNameWithoutAuthor': 'Philodendron',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Philodendron'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Heartleaf philodendron', 'Philodendron brazil'],
#     'scientificName': 'Philodendron cordatum Kunth ex Schott'},
#    'gbif': {'id': '2871314'},
#    'powo': {'id': '77073767-1'}},
#   {'score': 0.00174,
#    'species': {'scientificNameWithoutAuthor': 'Dracaena hanningtonii',
#     'scientificNameAuthorship': 'Baker',
#     'genus': {'scientificNameWithoutAuthor': 'Dracaena',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dracaena'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Blue Sansevieria'],
#     'scientificName': 'Dracaena hanningtonii Baker'},
#    'gbif': {'id': '5303896'},
#    'powo': {'id': '534229-1'}},
#   {'score': 0.00157,
#    'species': {'scientificNameWithoutAuthor': 'Agave cundinamarcensis',
#     'scientificNameAuthorship': 'A.Berger',
#     'genus': {'scientificNameWithoutAuthor': 'Agave',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Agave'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': [],
#     'scientificName': 'Agave cundinamarcensis A.Berger'},
#    'gbif': {'id': '2767106'},
#    'powo': {'id': '6447-2'},
#    'iucn': {'id': '114979348', 'category': 'EN'}},
#   {'score': 0.00151,
#    'species': {'scientificNameWithoutAuthor': 'Thaumatophyllum brasiliense',
#     'scientificNameAuthorship': '(Engl.) Sakur., Calazans & Mayo',
#     'genus': {'scientificNameWithoutAuthor': 'Thaumatophyllum',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Thaumatophyllum'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Brazilian Heartleaf Philodendrin'],
#     'scientificName': 'Thaumatophyllum brasiliense (Engl.) Sakur., Calazans & Mayo'},
#    'gbif': {'id': '9731469'},
#    'powo': {'id': '77178484-1'}},
#   {'score': 0.00145,
#    'species': {'scientificNameWithoutAuthor': 'Ornithogalum dubium',
#     'scientificNameAuthorship': 'Houtt.',
#     'genus': {'scientificNameWithoutAuthor': 'Ornithogalum',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Ornithogalum'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Sun Star', 'Orange star', 'Arabian starflower'],
#     'scientificName': 'Ornithogalum dubium Houtt.'},
#    'gbif': {'id': '2773605'},
#    'powo': {'id': '539181-1'}},
#   {'score': 0.00128,
#    'species': {'scientificNameWithoutAuthor': 'Costus arabicus',
#     'scientificNameAuthorship': 'L.',
#     'genus': {'scientificNameWithoutAuthor': 'Costus',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Costus'},
#     'family': {'scientificNameWithoutAuthor': 'Costaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Costaceae'},
#     'commonNames': ['Spiral Ginger'],
#     'scientificName': 'Costus arabicus L.'},
#    'gbif': {'id': '2756818'},
#    'powo': {'id': '796267-1'}},
#   {'score': 0.00126,
#    'species': {'scientificNameWithoutAuthor': 'Aloe striata',
#     'scientificNameAuthorship': 'Haw.',
#     'genus': {'scientificNameWithoutAuthor': 'Aloe',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Aloe'},
#     'family': {'scientificNameWithoutAuthor': 'Asphodelaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asphodelaceae'},
#     'commonNames': ['Coral aloe'],
#     'scientificName': 'Aloe striata Haw.'},
#    'gbif': {'id': '2778035'},
#    'powo': {'id': '529928-1'},
#    'iucn': {'id': '103634577', 'category': 'LC'}},
#   {'score': 0.00122,
#    'species': {'scientificNameWithoutAuthor': 'Gasteria pillansii',
#     'scientificNameAuthorship': 'Kensit',
#     'genus': {'scientificNameWithoutAuthor': 'Gasteria',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Gasteria'},
#     'family': {'scientificNameWithoutAuthor': 'Asphodelaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asphodelaceae'},
#     'commonNames': ['Cattle Tongue'],
#     'scientificName': 'Gasteria pillansii Kensit'},
#    'gbif': {'id': '2778759'},
#    'powo': {'id': '535820-1'}},
#   {'score': 0.00119,
#    'species': {'scientificNameWithoutAuthor': 'Maranta arundinacea',
#     'scientificNameAuthorship': 'L.',
#     'genus': {'scientificNameWithoutAuthor': 'Maranta',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Maranta'},
#     'family': {'scientificNameWithoutAuthor': 'Marantaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Marantaceae'},
#     'commonNames': ['Arrowroot', 'Maranta', 'West Indian arrowroot'],
#     'scientificName': 'Maranta arundinacea L.'},
#    'gbif': {'id': '2761352'},
#    'powo': {'id': '280408-2'}},
#   {'score': 0.00116,
#    'species': {'scientificNameWithoutAuthor': 'Tradescantia cerinthoides',
#     'scientificNameAuthorship': 'Kunth',
#     'genus': {'scientificNameWithoutAuthor': 'Tradescantia',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Tradescantia'},
#     'family': {'scientificNameWithoutAuthor': 'Commelinaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Commelinaceae'},
#     'commonNames': ['Flowering inch plant', 'Nanouk'],
#     'scientificName': 'Tradescantia cerinthoides Kunth'},
#    'gbif': {'id': '2765318'},
#    'powo': {'id': '173245-1'}}],
#  'version': '2023-09-12 (7.1)'}
